# %%
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets
# %matplotlib notebook

# %%
def draw_base(x):
#     ax.cla()
    plt.title("My Interactive Figure")
    global line
    line, = ax.plot(t, 2*np.sin(2*np.pi*t), color="blue")
    ax.set_xlabel("time")
    ax.set_ylabel('f(t)')
    x1, x2 = x
    ax.set_xlim(x1, x2)
    
def pickvel(event):
    ax.cla()
    draw_base(rangeX.value)
    if event.button == 1:
        current_pick = event.xdata
        tx = 'time=%.3f' % (current_pick)
        text=ax.text(current_pick,-1, tx, va="bottom", ha="left")
        vel_line = ax.axvline(current_pick, c="red", lw=0.5)
        
fig, ax = plt.subplots(figsize=(5,2))
t = np.arange(0,3,0.01)

## Range slider
rangeX = ipywidgets.widgets.FloatRangeSlider( 
    min=min(t), max=max(t), step=0.01,
    value=[min(t), max(t)])

draw_base(rangeX.value)

ipywidgets.interact(draw_base, x=rangeX)

button_event = fig.canvas.mpl_connect("button_press_event", pickvel)

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="687.2727272727273">
# interactive(children=(FloatRangeSlider(value=(0.0, 2.99), description='x', max=2.99, step=0.01), Output()), _d…

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

x = np.arange(100)
y = x**2

line, = ax.plot(x,y)

rangeX = ipywidgets.widgets.FloatRangeSlider( 
    min=0, max=100, step=1)

def update(x):
#     ax.cla()
    x1, x2 = x
    ax.set_xlim(x1, x2)
#     line.set_ydata(10)
#     tx = var
#     text=ax.text(50,2000, tx, va="bottom", ha="left")
#     fig.canvas.draw_idle()
#     print(var)
    
# myfunc = rangeX.observe(update, "value")
# myfunc = ipywidgets.interact(update)

ipywidgets.interact(update, x=rangeX)
# ipywidgets.widgets.interactive(update, x=rangeX)

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(FloatRangeSlider(value=(25.0, 75.0), description='x', step=1.0), Output()), _dom_classes…

# %%
test = ipywidgets.widgets.FloatRangeSlider(
    value=[5, 7.5],
    min=0,
    max=10.0,
    step=0.1,
    description='slide it:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
)

# def update(var):
#     print(var)

# test.observe(update, "value")

def f(x):
    return x

ipywidgets.interact(test)
# Out:
# interactive(children=(Output(),), _dom_classes=('widget-interact',))
# FloatRangeSlider(value=(5.0, 7.5), continuous_update=False, description='slide it:', max=10.0, readout_format=…

# %%
ipywidgets.widgets.FloatRangeSlider(
    value=[5, 7.5],
    min=0,
    max=10.0,
    step=0.1,
    description='Test:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
)
# Out:
# FloatRangeSlider(value=(5.0, 7.5), continuous_update=False, description='Test:', max=10.0, readout_format='.1f…

# %%
amp = ipywidgets.widgets.FloatSlider(min=1,max=10,value=1,description="Amp")
phase = ipywidgets.widgets.FloatSlider(min=0,max=5,value=0,description="Phase")
freq = ipywidgets.widgets.FloatSlider(min=1,max=10,value=0,description="Freq")
x = ipywidgets.widgets.FloatRangeSlider(min=0,max=1)

f,ax = plt.subplots(1,figsize=(3,3))
ax.set_ylim([-10,10])
plt.suptitle("Sine Wave")

def update_plot(x,amp,phase,freq):
    ax.clear()
    x1, x2 = x
    xt = np.linspace(x1,x2,50)
    y = amp*np.sin(2*np.pi*(freq*xt+phase))
    ax.plot(xt,y)
    ax.set_ylim([-10,10])
    ax.set_xlim([x1,x2])
    ax.grid()
    plt.show()

ipywidgets.widgets.interactive(update_plot,x=x,amp=amp,phase=phase,freq=freq)
# Out:
# <img src="data:image/png;base64,..." width="412.3636363636364">
# interactive(children=(FloatRangeSlider(value=(0.25, 0.75), description='x', max=1.0), FloatSlider(value=1.0, d…

# %%
x = np.linspace(0, 2 * np.pi)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
line, = ax.plot(x, np.sin(x))

def update(w = 1.0):
    line.set_ydata(np.sin(w * x))
    fig.canvas.draw_idle()
    
plt.tight_layout()

myfunc = ipywidgets.interact(update)
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(FloatSlider(value=1.0, description='w', max=3.0, min=-1.0), Output()), _dom_classes=('wi…
